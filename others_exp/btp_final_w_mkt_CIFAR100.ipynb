# %%
import torch
from torchvision.datasets import CIFAR100
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import random
from sklearn.cluster import KMeans
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
import numpy as np
from typing import List, Tuple
import pickle
import time
from torch.utils.data import ConcatDataset, Dataset, Subset
# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %%
train_dataset = CIFAR100('/home/vishal1/Desktop/nitin/Test1.1/outputforpaper/CIFAR100', train=True, download=True, transform=transforms.ToTensor())
test_dataset = CIFAR100('/home/vishal1/Desktop/nitin/Test1.1/outputforpaper/CIFAR100', train=False, download=True, transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
classes = 100
input_dim = 3 * 32 * 32
num_clients = 70
rounds = 100
batch_size = 32
in_group_rounds = 3
epochs_per_client = 10 
learning_rate = 2e-2
num_malicious_clients = 5

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
            return len(self.dl)

device = get_device()


def average_models(new_model, next, scale):
    if new_model == None:
        new_model = next
        for key in new_model:
            new_model[key] = new_model[key] * scale
    else:
        for key in new_model:
            new_model[key] = new_model[key] + (next[key] * scale)
    return new_model

# %%
class FederatedNet(torch.nn.Module):    
    # def __init__(self):
    #     super().__init__()
    #     # Update input channels to 3 for RGB images
    #     self.layer1 = torch.nn.Sequential(
    #         torch.nn.Conv2d(3, 16, kernel_size=5, padding=2),
    #         torch.nn.BatchNorm2d(16),
    #         torch.nn.ReLU(),
    #         torch.nn.MaxPool2d(2))
        
    #     self.layer2 = torch.nn.Sequential(
    #         torch.nn.Conv2d(16, 32, kernel_size=5, padding=2),
    #         torch.nn.BatchNorm2d(32),
    #         torch.nn.ReLU(),
    #         torch.nn.MaxPool2d(2))
        
    #     self.fc = torch.nn.Linear(8 * 8 * 32, 10)
    
    # def forward(self, x):
    #     out = self.layer1(x)
    #     out = self.layer2(out)
    #     out = out.view(out.size(0), -1)
    #     out = self.fc(out)
    #     return 
    
    def __init__(self):
        super().__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(3, 64, kernel_size=3, padding=1),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            torch.nn.Dropout(0.3)
        )
        
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(64, 128, kernel_size=3, padding=1),
            torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            torch.nn.Dropout(0.4)
        )
        
        self.layer3 = torch.nn.Sequential(
            torch.nn.Conv2d(128, 256, kernel_size=3, padding=1),
            torch.nn.BatchNorm2d(256),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            torch.nn.Dropout(0.4)
        )
        
        self.fc1 = torch.nn.Linear(4 * 4 * 256, 512)
        self.fc2 = torch.nn.Linear(512, 100)
        
        self.dropout_fc = torch.nn.Dropout(0.5)

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        x = x.view(x.size(0), -1)
        x = self.dropout_fc(torch.nn.functional.relu(self.fc1(x)))
        x = self.fc2(x)
        
        return x

    
    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))
    
    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)
    
    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history
    
    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %%
def partition_data_label_quantity(
    num_clients, labels_per_client, train_dataset, total_train_size, seed=42
):
    trainset = train_dataset
    prng = np.random.default_rng(seed)

    targets = trainset.targets
    if isinstance(targets, list):
        targets = np.array(targets)
    if isinstance(targets, torch.Tensor):
        targets = targets.numpy()

    num_classes = len(set(targets))

    if labels_per_client > num_classes:
        raise ValueError(f"labels_per_client cannot be greater than the number of classes ({num_classes})")
    
    times = [0 for _ in range(num_classes)]
    contains = []

    for i in range(num_clients):
        current = [i % num_classes]
        times[i % num_classes] += 1
        j = 1
        while j < labels_per_client:
            index = prng.choice(num_classes, 1)[0]
            if index not in current:
                current.append(index)
                times[index] += 1
                j += 1
        contains.append(current)

    classes_assigned = set([cls for client_classes in contains for cls in client_classes])
    unassigned_classes = set(range(num_classes)) - classes_assigned
    
    if unassigned_classes:
        print(f"Warning: The following classes were not assigned to any client: {sorted(unassigned_classes)}")
        
    for unassigned_class in unassigned_classes:
        random_client = prng.choice(num_clients)
        contains[random_client].append(unassigned_class)
        times[unassigned_class] += 1

    idx_clients: List[List[int]] = [[] for _ in range(num_clients)]
    for i in range(num_classes):
        idx_k = np.where(targets == i)[0]
        prng.shuffle(idx_k)
        
        if times[i] > 0:
            idx_k_split = np.array_split(idx_k, times[i])
            ids = 0
            for j in range(num_clients):
                if i in contains[j]:
                    idx_clients[j] += idx_k_split[ids].tolist()
                    ids += 1
    
    trainsets_per_client = [Subset(train_dataset, idxs) for idxs in idx_clients]

    return trainsets_per_client

# %%
labels_per_client = 5
client_datasets = partition_data_label_quantity(num_clients, labels_per_client, train_dataset, len(train_dataset))
# Out:
# Warning: The following classes were not assigned to any client: [86, 87]

# %%
import numpy as np

class memory:

    def __init__(self, batch_number, batch_size):
        self.batch_number = batch_number
        self.batch_size = batch_size
        self.matrix = np.zeros((batch_number, batch_size), dtype=int)
        self.add_time = 0

    def add_number(self, batch_no, true_array):
        if batch_no >= self.batch_number:
            print(f"Warning: Batch number {batch_no} out of range. Skipping this entry.")
            return
        # Ensure true_array length matches batch_size by padding or truncating as necessary
        true_array = np.pad(true_array, (0, max(0, self.batch_size - len(true_array))), mode='constant')[:self.batch_size]
        self.matrix[batch_no] += true_array


    def add(self):
        self.add_time = self.add_time + 1

    def get_ambiguous(self, number):
        temp_matrix = self.matrix
        temp_matrix = np.abs(temp_matrix - np.ones(self.matrix.shape) * self.add_time * 0.5)
        temp_array = np.reshape(temp_matrix, self.matrix.shape[0] * self.matrix.shape[1])
        temp = list(map(list, zip(range(len(temp_array)), temp_array)))
        small = sorted(temp, key=lambda x: x[1], reverse=False)
        small_array = []
        for i in range(number):
            small_array.append(small[i][0])
        return small_array

# %%
from torch.utils.data import DataLoader
import torch
from torch import nn
import numpy as np
# import dnn_model  # Assumed custom DNN model import
# from memory import memory  # Assumed memory module import


class KMT:
    learning_rate = 0.01
    momentum = 0.5
    batch_size = 32
    batch_number = 1000
    train_loss = []
    test_loss = []
    test_accuracy = []

    def __init__(self, dataset, index, test_loader):
        # Load training set and initialize test loader
        self.load_train_set(dataset, index)
        self.test_loader = test_loader
        self.model = FederatedNet()  # Use FederatedNet model here
        self.criterion = nn.CrossEntropyLoss()
        self.distillation_criterion = nn.KLDivLoss(reduction='batchmean')
        self.optimizer = torch.optim.SGD(self.model.parameters(), lr=self.learning_rate, momentum=self.momentum)
        self.memory = memory(self.batch_number, self.batch_size)

    def load_train_set(self, dataset, index):
        # Subset and DataLoader for training
        train_dataset = torch.utils.data.Subset(dataset, index.astype(int))
        self.train_loader = DataLoader(train_dataset, batch_size=self.batch_size, shuffle=True)

    def train(self):
        # Standard training without distillation
        self.memory.add()  # Initialize memory
        running_loss = 0
        batch_number = 0

        for images, labels in self.train_loader:
            self.optimizer.zero_grad()
            output = self.model(images)
            loss = self.criterion(output, labels)

            # Accuracy calculation for memory tracking
            log_ps = torch.log_softmax(output, dim=1)
            ps = torch.exp(log_ps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = (top_class == labels.view(*top_class.shape)).numpy().squeeze().astype(int).transpose()
            self.memory.add_number(batch_number, equals)

            # Backpropagation and optimizer step
            loss.backward()
            self.optimizer.step()
            running_loss += loss.item()
            batch_number += 1

        self.train_loss.append(running_loss / len(self.train_loader))

    def distillation_train(self, images, labels, other_soft_decision):
        # Knowledge distillation training with soft labels from other clients
        self.optimizer.zero_grad()
        output = self.model(images)
        loss1 = self.criterion(output, labels)
        loss2 = self.distillation_criterion(torch.log_softmax(output, dim=1), other_soft_decision)
        loss = loss1 + loss2

        log_ps = torch.log_softmax(output, dim=1)
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = (top_class == labels.view(*top_class.shape)).numpy().squeeze().astype(int).transpose()

        # Backpropagation and optimizer step
        loss.backward()
        self.optimizer.step()
        return equals

    def test(self):
        accuracy = 0
        loss = 0
        for images, labels in self.test_loader:
            output = self.model(images)
            log_ps = torch.log_softmax(output, dim=1)
            ps = torch.exp(log_ps)
            loss += self.criterion(log_ps, labels)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor))
        self.test_loss.append((loss / len(self.test_loader)).item())
        self.test_accuracy.append((accuracy / len(self.test_loader)).item())
        return accuracy / len(self.test_loader)

    def save_model(self, filename="temp_model.pt"):
        torch.save(self.model.state_dict(), filename)

    def load_model(self, filename="temp_model.pt"):
        self.model.load_state_dict(torch.load(filename))

    def get_ambiguous_data(self, array):
        np.sort(array)
        batch_number = 0
        ambiguous_images = []
        ambiguous_labels = []
        for images, labels in self.train_loader:
            for no in array:
                if int(no / self.batch_size) == batch_number:
                    column = np.mod(no, self.batch_size)
                    ambiguous_images.append(images[column])
                    ambiguous_labels.append(labels[column])
            batch_number += 1
        ambiguous_images = torch.stack(ambiguous_images)
        ambiguous_labels = torch.stack(ambiguous_labels)
        return ambiguous_images, ambiguous_labels

    def test_data(self, images, labels):
        loss = 0
        output = self.model(images)
        log_ps = torch.log_softmax(output, dim=1)
        loss += self.criterion(log_ps, labels)
        return loss

    def test_data_accuracy(self, images, labels):
        output = self.model(images)
        log_ps = torch.log_softmax(output, dim=1)
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy = torch.mean(equals.type(torch.FloatTensor))
        return accuracy

# %% [markdown]
# FL

# %%
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset
    
    def get_dataset_size(self):
        return len(self.dataset)
    
    def get_client_id(self):
        return self.client_id
    
    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.load_state_dict(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        return net.state_dict()

# %%
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %%
fl_start_time = time.time()

global_net = to_device(FederatedNet(), device)
history_FL = []
traffic=[]
weights=[]
load_model=None
total_length_dataset=len(train_dataset)
for i in range(rounds):
    curr_parameters = global_net.state_dict()
    new_model=None
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size()/total_length_dataset
        new_model=average_models(new_model,client_parameters,fraction)
    load_model=new_model.copy()
    params = list(load_model)
    total_norm = 0.0
    for key, value in load_model.items():
        total_norm += torch.norm(value.view(-1)).item()
    weights.append(total_norm)
    global_net.load_state_dict(new_model)
    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(test_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4), 
            round(dev_loss, 4), round(dev_acc, 4)))
    traffic.append(2*num_clients)
    history_FL.append((train_acc, dev_acc,i))

fl_end_time = time.time()
fl_time = fl_end_time - fl_start_time
# Out:
# After round 1, train_loss = 4.597, dev_loss = 4.6016, dev_acc = 0.0139
#
# After round 2, train_loss = 4.5555, dev_loss = 4.5541, dev_acc = 0.0252
#
# After round 3, train_loss = 4.4981, dev_loss = 4.4968, dev_acc = 0.0354
#
# After round 4, train_loss = 4.4274, dev_loss = 4.4261, dev_acc = 0.0467
#
# After round 5, train_loss = 4.3586, dev_loss = 4.3671, dev_acc = 0.0575
#
# After round 6, train_loss = 4.2954, dev_loss = 4.3039, dev_acc = 0.0636
#
# After round 7, train_loss = 4.2328, dev_loss = 4.2389, dev_acc = 0.0713
#
# After round 8, train_loss = 4.1726, dev_loss = 4.1791, dev_acc = 0.0786
#
# After round 9, train_loss = 4.1189, dev_loss = 4.1262, dev_acc = 0.091
#
# After round 10, train_loss = 4.065, dev_loss = 4.0836, dev_acc = 0.0934
#
# After round 11, train_loss = 4.0181, dev_loss = 4.03, dev_acc = 0.1009
#
# After round 12, train_loss = 3.968, dev_loss = 3.9969, dev_acc = 0.104
#
# After round 13, train_loss = 3.9189, dev_loss = 3.9333, dev_acc = 0.1083
#
# After round 14, train_loss = 3.8771, dev_loss = 3.8984, dev_acc = 0.1131
#
# After round 15, train_loss = 3.8359, dev_loss = 3.8647, dev_acc = 0.1239
#
# After round 16, train_loss = 3.805, dev_loss = 3.8297, dev_acc = 0.1282
#
# After round 17, train_loss = 3.7587, dev_loss = 3.785, dev_acc = 0.1319
#
# After round 18, train_loss = 3.7327, dev_loss = 3.7632, dev_acc = 0.1333
#
# After round 19, train_loss = 3.6914, dev_loss = 3.7237, dev_acc = 0.1399
#
# After round 20, train_loss = 3.6573, dev_loss = 3.6963, dev_acc = 0.1432
#
# After round 21, train_loss = 3.6159, dev_loss = 3.6703, dev_acc = 0.1464
#
# After round 22, train_loss = 3.5864, dev_loss = 3.6344, dev_acc = 0.153
#
# After round 23, train_loss = 3.5597, dev_loss = 3.6082, dev_acc = 0.1569
#
# After round 24, train_loss = 3.5275, dev_loss = 3.5849, dev_acc = 0.1582
#
# After round 25, train_loss = 3.5098, dev_loss = 3.5617, dev_acc = 0.1622
#
# After round 26, train_loss = 3.481, dev_loss = 3.5341, dev_acc = 0.1668
#
# After round 27, train_loss = 3.459, dev_loss = 3.5216, dev_acc = 0.1667
#
# After round 28, train_loss = 3.4336, dev_loss = 3.4787, dev_acc = 0.1747
#
# After round 29, train_loss = 3.4163, dev_loss = 3.4811, dev_acc = 0.1733
#
# After round 30, train_loss = 3.3883, dev_loss = 3.4638, dev_acc = 0.1781
#
# After round 31, train_loss = 3.3616, dev_loss = 3.4323, dev_acc = 0.1863
#
# After round 32, train_loss = 3.3468, dev_loss = 3.4103, dev_acc = 0.1841
#
# After round 33, train_loss = 3.3231, dev_loss = 3.4045, dev_acc = 0.1875
#
# After round 34, train_loss = 3.3154, dev_loss = 3.3763, dev_acc = 0.1938
#
# After round 35, train_loss = 3.2933, dev_loss = 3.3642, dev_acc = 0.1855
#
# After round 36, train_loss = 3.2678, dev_loss = 3.3449, dev_acc = 0.193
#
# After round 37, train_loss = 3.2486, dev_loss = 3.3384, dev_acc = 0.1947
#
# After round 38, train_loss = 3.2308, dev_loss = 3.3096, dev_acc = 0.1983
#
# After round 39, train_loss = 3.2132, dev_loss = 3.3219, dev_acc = 0.1939
#
# After round 40, train_loss = 3.2108, dev_loss = 3.302, dev_acc = 0.1994
#
# After round 41, train_loss = 3.1812, dev_loss = 3.2861, dev_acc = 0.2036
#
# After round 42, train_loss = 3.1815, dev_loss = 3.2689, dev_acc = 0.2065
#
# After round 43, train_loss = 3.1658, dev_loss = 3.2514, dev_acc = 0.2079
#
# After round 44, train_loss = 3.1449, dev_loss = 3.2619, dev_acc = 0.2044
#
# After round 45, train_loss = 3.1317, dev_loss = 3.2378, dev_acc = 0.2093
#
# After round 46, train_loss = 3.1266, dev_loss = 3.2217, dev_acc = 0.2168
#
# After round 47, train_loss = 3.1097, dev_loss = 3.2223, dev_acc = 0.215
#
# After round 48, train_loss = 3.1013, dev_loss = 3.2222, dev_acc = 0.2151
#
# After round 49, train_loss = 3.0872, dev_loss = 3.2024, dev_acc = 0.2143
#
# After round 50, train_loss = 3.0854, dev_loss = 3.2068, dev_acc = 0.2157
#
# After round 51, train_loss = 3.0732, dev_loss = 3.1889, dev_acc = 0.2179
#
# After round 52, train_loss = 3.0557, dev_loss = 3.1797, dev_acc = 0.2146
#
# After round 53, train_loss = 3.0428, dev_loss = 3.1742, dev_acc = 0.2173
#
# After round 54, train_loss = 3.0334, dev_loss = 3.1493, dev_acc = 0.2231
#
# After round 55, train_loss = 3.0184, dev_loss = 3.1451, dev_acc = 0.2174
#
# After round 56, train_loss = 3.0081, dev_loss = 3.1408, dev_acc = 0.225
#
# After round 57, train_loss = 3.0042, dev_loss = 3.1218, dev_acc = 0.2294
#
# After round 58, train_loss = 2.9926, dev_loss = 3.1419, dev_acc = 0.2273
#
# After round 59, train_loss = 2.9889, dev_loss = 3.1502, dev_acc = 0.225
#
# After round 60, train_loss = 2.9788, dev_loss = 3.1258, dev_acc = 0.229
#
# After round 61, train_loss = 2.963, dev_loss = 3.1215, dev_acc = 0.2277
#
# After round 62, train_loss = 2.9581, dev_loss = 3.1146, dev_acc = 0.2244
#
# After round 63, train_loss = 2.9483, dev_loss = 3.0829, dev_acc = 0.2333
#
# After round 64, train_loss = 2.9454, dev_loss = 3.1081, dev_acc = 0.2278
#
# After round 65, train_loss = 2.9294, dev_loss = 3.0969, dev_acc = 0.2291
#
# After round 66, train_loss = 2.9228, dev_loss = 3.0841, dev_acc = 0.2321
#
# After round 67, train_loss = 2.9265, dev_loss = 3.0907, dev_acc = 0.2359
#
# After round 68, train_loss = 2.9105, dev_loss = 3.0824, dev_acc = 0.2338
#
# After round 69, train_loss = 2.9028, dev_loss = 3.0881, dev_acc = 0.2343
#
# After round 70, train_loss = 2.8965, dev_loss = 3.0564, dev_acc = 0.244
#
# After round 71, train_loss = 2.8942, dev_loss = 3.071, dev_acc = 0.2373
#
# After round 72, train_loss = 2.8783, dev_loss = 3.0668, dev_acc = 0.2429
#
# After round 73, train_loss = 2.8815, dev_loss = 3.0487, dev_acc = 0.2433
#
# After round 74, train_loss = 2.8776, dev_loss = 3.0633, dev_acc = 0.2401
#
# After round 75, train_loss = 2.8648, dev_loss = 3.0534, dev_acc = 0.2384
#
# After round 76, train_loss = 2.8627, dev_loss = 3.0466, dev_acc = 0.2421
#
# After round 77, train_loss = 2.8546, dev_loss = 3.0497, dev_acc = 0.2434
#
# After round 78, train_loss = 2.8468, dev_loss = 3.0351, dev_acc = 0.2464
#
# After round 79, train_loss = 2.8405, dev_loss = 3.0445, dev_acc = 0.248
#
# After round 80, train_loss = 2.8342, dev_loss = 3.0251, dev_acc = 0.2472
#
# After round 81, train_loss = 2.8307, dev_loss = 3.0111, dev_acc = 0.25
#
# After round 82, train_loss = 2.8317, dev_loss = 3.0233, dev_acc = 0.2455
#
# After round 83, train_loss = 2.8233, dev_loss = 3.0304, dev_acc = 0.2475
#
# After round 84, train_loss = 2.8145, dev_loss = 3.0179, dev_acc = 0.2456
#
# After round 85, train_loss = 2.8141, dev_loss = 3.0171, dev_acc = 0.2493
#
# After round 86, train_loss = 2.7949, dev_loss = 2.997, dev_acc = 0.2479
#
# After round 87, train_loss = 2.8011, dev_loss = 2.9899, dev_acc = 0.2537
#
# After round 88, train_loss = 2.8025, dev_loss = 3.0116, dev_acc = 0.2481
#
# After round 89, train_loss = 2.783, dev_loss = 2.9911, dev_acc = 0.2578
#
# After round 90, train_loss = 2.7817, dev_loss = 3.0236, dev_acc = 0.2425
#
# After round 91, train_loss = 2.7835, dev_loss = 3.011, dev_acc = 0.251
#
# After round 92, train_loss = 2.7777, dev_loss = 2.9877, dev_acc = 0.2527
#
# After round 93, train_loss = 2.769, dev_loss = 2.9911, dev_acc = 0.2513
#
# After round 94, train_loss = 2.7604, dev_loss = 3.017, dev_acc = 0.2536
#
# After round 95, train_loss = 2.7563, dev_loss = 3.004, dev_acc = 0.2562
#
# After round 96, train_loss = 2.756, dev_loss = 3.003, dev_acc = 0.2537
#
# After round 97, train_loss = 2.7537, dev_loss = 3.0028, dev_acc = 0.2508
#
# After round 98, train_loss = 2.7497, dev_loss = 2.9868, dev_acc = 0.2563
#
# After round 99, train_loss = 2.7459, dev_loss = 3.0025, dev_acc = 0.2546
#
# After round 100, train_loss = 2.744, dev_loss = 3.0029, dev_acc = 0.2572

# %%
plt.plot([i + 1 for i in range(len(history_FL))], [history_FL[i][0] for i in range(len(history_FL))], color='r', label='train accuracy')
plt.plot([i + 1 for i in range(len(history_FL))], [history_FL[i][1] for i in range(len(history_FL))], color='b', label='dev accuracy')
plt.legend()
plt.title("Rounds vs Accuracy")
plt.xlabel("Number of rounds")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# DFL

# %%
class Client:
    def __init__(self, client_id, dataset, test_loader):
        self.client_id = client_id
        self.dataset = dataset
        # self.test_loader = test_loader
        self.kmt = KMT(dataset, index=np.arange(len(dataset)), test_loader=test_loader)
        self.client_data = []

    def get_dataset_size(self):
        return len(self.dataset)
    
    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict, other_soft_decisions=None):
        # Load initial parameters
        self.kmt.model.load_state_dict(parameters_dict)

        # Standard training
        self.kmt.train()

        # Knowledge distillation using soft labels from other clients (if available)
        if other_soft_decisions is not None:
            for images, labels in self.kmt.train_loader:
                if images in other_soft_decisions:
                    other_soft_decision = other_soft_decisions[images]
                    self.kmt.distillation_train(images, labels, other_soft_decision)
        
        # Return the updated model parameters
        return self.kmt.model.state_dict()

    def recieve_parameters(self, client_id, client_parameter, fraction):
        client_object = {"client_id": client_id, "client_parameter": client_parameter, "fraction": fraction}
        self.client_data.append(client_object)

    def aggregated_parameters(self):
        local_aggregated_model = None
        for i in range(len(self.client_data)):
            local_aggregated_model = average_models(local_aggregated_model, self.client_data[i]["client_parameter"], self.client_data[i]["fraction"])
        self.client_data.clear()
        return local_aggregated_model

# %%
from torch.utils.data import Subset

# Example: Split `dataset` into `num_clients` subsets
client_datasets = []
dataset_size = len(train_dataset)
subset_size = dataset_size // num_clients
test_loader = DataLoader(test_dataset, batch_size=200, shuffle=True)

# Split the dataset into chunks for each client
for i in range(num_clients):
    indices = range(i * subset_size, (i + 1) * subset_size)
    client_datasets.append(Subset(train_dataset, indices))

# Now initialize the clients
clients = [Client(i, client_datasets[i], test_loader) for i in range(num_clients)]

# %%
import time
import torch

# Assume FederatedNet, average_models, and other necessary imports are already defined

dfl_start_time = time.time()

global_net = to_device(FederatedNet(), device)
curr_parameters = global_net.state_dict()
history_dfl = []
weights = []
traffic = []
load_model = None
total_data_size = len(train_dataset)

for i in range(rounds):
    new_model = None
    soft_decisions = {}

    for client in clients:
        fraction = client.get_dataset_size() / total_data_size

        client_parameters = client.train(curr_parameters, other_soft_decisions=soft_decisions if i > 0 else None)
        
        for images, labels in client.kmt.train_loader:
            output = client.kmt.model(images)
            soft_decisions[client.get_client_id()] = torch.softmax(output, dim=1).detach()

        for clt in clients:
            clt.recieve_parameters(client.get_client_id(), client_parameters, fraction)

        new_model = average_models(new_model, client_parameters, fraction)

    load_model = new_model.copy()
    global_net.load_state_dict(new_model)
    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(test_dataset)
    
    print(f'After round {i + 1}, train_loss = {round(train_loss, 4)}, dev_loss = {round(dev_loss, 4)}, dev_acc = {round(dev_acc, 4)}')
    history_dfl.append((train_acc, dev_acc, i))
    traffic.append(len(clients) * len(clients) - 1)  # Adjust traffic tracking logic

dfl_end_time = time.time()
dfl_time = dfl_end_time - dfl_start_time
print(f"Total training time: {dfl_time:.2f} seconds")

torch.save(global_net.state_dict(), "final_global_model.pt")
# Out:
# After round 1, train_loss = 4.6006, dev_loss = 4.6005, dev_acc = 0.013
# After round 2, train_loss = 4.5907, dev_loss = 4.5904, dev_acc = 0.0156
# After round 3, train_loss = 4.5787, dev_loss = 4.5793, dev_acc = 0.0211
# After round 4, train_loss = 4.5574, dev_loss = 4.5599, dev_acc = 0.0232
# After round 5, train_loss = 4.5184, dev_loss = 4.5188, dev_acc = 0.0325
# After round 6, train_loss = 4.4699, dev_loss = 4.471, dev_acc = 0.0314
# After round 7, train_loss = 4.42, dev_loss = 4.4206, dev_acc = 0.0359
# After round 8, train_loss = 4.3735, dev_loss = 4.3692, dev_acc = 0.0428
# After round 9, train_loss = 4.3311, dev_loss = 4.3329, dev_acc = 0.0434
# After round 10, train_loss = 4.2867, dev_loss = 4.292, dev_acc = 0.0506
# After round 11, train_loss = 4.2474, dev_loss = 4.2568, dev_acc = 0.0491
# After round 12, train_loss = 4.2095, dev_loss = 4.2144, dev_acc = 0.063
# After round 13, train_loss = 4.1773, dev_loss = 4.1834, dev_acc = 0.0603
# After round 14, train_loss = 4.1423, dev_loss = 4.1477, dev_acc = 0.0641
# After round 15, train_loss = 4.1115, dev_loss = 4.1199, dev_acc = 0.0685
# After round 16, train_loss = 4.0784, dev_loss = 4.0916, dev_acc = 0.0742
# After round 17, train_loss = 4.0531, dev_loss = 4.0612, dev_acc = 0.0765
# After round 18, train_loss = 4.0223, dev_loss = 4.039, dev_acc = 0.0774
# After round 19, train_loss = 4.0027, dev_loss = 4.0047, dev_acc = 0.0845
# After round 20, train_loss = 3.9801, dev_loss = 3.995, dev_acc = 0.0872
# After round 21, train_loss = 3.9569, dev_loss = 3.9664, dev_acc = 0.0979
# After round 22, train_loss = 3.9348, dev_loss = 3.9503, dev_acc = 0.0931
# After round 23, train_loss = 3.9132, dev_loss = 3.9325, dev_acc = 0.0969
# After round 24, train_loss = 3.9007, dev_loss = 3.9106, dev_acc = 0.0968
# After round 25, train_loss = 3.878, dev_loss = 3.8962, dev_acc = 0.1038
# After round 26, train_loss = 3.8635, dev_loss = 3.8785, dev_acc = 0.1081
# After round 27, train_loss = 3.8493, dev_loss = 3.8664, dev_acc = 0.1056
# After round 28, train_loss = 3.8314, dev_loss = 3.8455, dev_acc = 0.1121
# After round 29, train_loss = 3.8164, dev_loss = 3.8317, dev_acc = 0.1126
# After round 30, train_loss = 3.8005, dev_loss = 3.8186, dev_acc = 0.1172
# After round 31, train_loss = 3.7814, dev_loss = 3.7941, dev_acc = 0.1214
# After round 32, train_loss = 3.7716, dev_loss = 3.7887, dev_acc = 0.1212
# After round 33, train_loss = 3.7558, dev_loss = 3.7766, dev_acc = 0.1233
# After round 34, train_loss = 3.741, dev_loss = 3.7603, dev_acc = 0.1307
# After round 35, train_loss = 3.7299, dev_loss = 3.7484, dev_acc = 0.132
# After round 36, train_loss = 3.7102, dev_loss = 3.7264, dev_acc = 0.1317
# After round 37, train_loss = 3.7022, dev_loss = 3.7112, dev_acc = 0.1352
# After round 38, train_loss = 3.6875, dev_loss = 3.7104, dev_acc = 0.1315
# After round 39, train_loss = 3.6744, dev_loss = 3.7003, dev_acc = 0.1349
# After round 40, train_loss = 3.6574, dev_loss = 3.6859, dev_acc = 0.1395
# After round 41, train_loss = 3.6525, dev_loss = 3.6675, dev_acc = 0.138
# After round 42, train_loss = 3.6364, dev_loss = 3.6608, dev_acc = 0.1417
# After round 43, train_loss = 3.6231, dev_loss = 3.6452, dev_acc = 0.1465
# After round 44, train_loss = 3.6127, dev_loss = 3.6401, dev_acc = 0.146
# After round 45, train_loss = 3.6018, dev_loss = 3.6224, dev_acc = 0.1506
# After round 46, train_loss = 3.5858, dev_loss = 3.6086, dev_acc = 0.1483
# After round 47, train_loss = 3.5747, dev_loss = 3.6024, dev_acc = 0.1532
# After round 48, train_loss = 3.5613, dev_loss = 3.5916, dev_acc = 0.1592
# After round 49, train_loss = 3.5579, dev_loss = 3.5766, dev_acc = 0.1586
# After round 50, train_loss = 3.5451, dev_loss = 3.573, dev_acc = 0.1592
# After round 51, train_loss = 3.5337, dev_loss = 3.5579, dev_acc = 0.1592
# After round 52, train_loss = 3.5251, dev_loss = 3.5501, dev_acc = 0.1633
# After round 53, train_loss = 3.5172, dev_loss = 3.54, dev_acc = 0.1656
# After round 54, train_loss = 3.508, dev_loss = 3.5291, dev_acc = 0.1636
# After round 55, train_loss = 3.4948, dev_loss = 3.5143, dev_acc = 0.1713
# After round 56, train_loss = 3.4851, dev_loss = 3.5067, dev_acc = 0.1664
# After round 57, train_loss = 3.4733, dev_loss = 3.509, dev_acc = 0.1693
# After round 58, train_loss = 3.4689, dev_loss = 3.4891, dev_acc = 0.1743
# After round 59, train_loss = 3.4597, dev_loss = 3.4847, dev_acc = 0.1763
# After round 60, train_loss = 3.4496, dev_loss = 3.4795, dev_acc = 0.1796
# After round 61, train_loss = 3.4406, dev_loss = 3.4704, dev_acc = 0.1753
# After round 62, train_loss = 3.433, dev_loss = 3.4591, dev_acc = 0.176
# After round 63, train_loss = 3.4177, dev_loss = 3.4604, dev_acc = 0.1826
# After round 64, train_loss = 3.412, dev_loss = 3.4495, dev_acc = 0.1813
# After round 65, train_loss = 3.4054, dev_loss = 3.436, dev_acc = 0.1812
# After round 66, train_loss = 3.3922, dev_loss = 3.4247, dev_acc = 0.1861
# After round 67, train_loss = 3.3883, dev_loss = 3.4177, dev_acc = 0.1869
# After round 68, train_loss = 3.3772, dev_loss = 3.4095, dev_acc = 0.1868
# After round 69, train_loss = 3.3694, dev_loss = 3.4149, dev_acc = 0.186
# After round 70, train_loss = 3.3613, dev_loss = 3.3966, dev_acc = 0.1874
# After round 71, train_loss = 3.3557, dev_loss = 3.3893, dev_acc = 0.192
# After round 72, train_loss = 3.3463, dev_loss = 3.3804, dev_acc = 0.195
# After round 73, train_loss = 3.3387, dev_loss = 3.3781, dev_acc = 0.192
# After round 74, train_loss = 3.3278, dev_loss = 3.3567, dev_acc = 0.1941
# After round 75, train_loss = 3.3256, dev_loss = 3.3603, dev_acc = 0.1971
# After round 76, train_loss = 3.3145, dev_loss = 3.351, dev_acc = 0.1981
# After round 77, train_loss = 3.3065, dev_loss = 3.3442, dev_acc = 0.1998
# After round 78, train_loss = 3.3008, dev_loss = 3.3375, dev_acc = 0.2
# After round 79, train_loss = 3.2911, dev_loss = 3.3308, dev_acc = 0.1981
# After round 80, train_loss = 3.2813, dev_loss = 3.3303, dev_acc = 0.2019
# After round 81, train_loss = 3.2768, dev_loss = 3.3115, dev_acc = 0.2051
# After round 82, train_loss = 3.2668, dev_loss = 3.3074, dev_acc = 0.2009
# After round 83, train_loss = 3.2684, dev_loss = 3.3063, dev_acc = 0.2098
# After round 84, train_loss = 3.2555, dev_loss = 3.2873, dev_acc = 0.2104
# After round 85, train_loss = 3.2461, dev_loss = 3.2997, dev_acc = 0.2024
# After round 86, train_loss = 3.2383, dev_loss = 3.2746, dev_acc = 0.2072
# After round 87, train_loss = 3.2315, dev_loss = 3.268, dev_acc = 0.2123
# After round 88, train_loss = 3.2224, dev_loss = 3.2692, dev_acc = 0.2076
# After round 89, train_loss = 3.2164, dev_loss = 3.2653, dev_acc = 0.2161
# After round 90, train_loss = 3.2067, dev_loss = 3.2484, dev_acc = 0.2177
# After round 91, train_loss = 3.2056, dev_loss = 3.2436, dev_acc = 0.2162
# After round 92, train_loss = 3.1933, dev_loss = 3.2374, dev_acc = 0.2207
# After round 93, train_loss = 3.1894, dev_loss = 3.2231, dev_acc = 0.2278
# After round 94, train_loss = 3.182, dev_loss = 3.2259, dev_acc = 0.2213
# After round 95, train_loss = 3.1777, dev_loss = 3.2203, dev_acc = 0.2247
# After round 96, train_loss = 3.1711, dev_loss = 3.209, dev_acc = 0.2206
# After round 97, train_loss = 3.1643, dev_loss = 3.2032, dev_acc = 0.2279
# After round 98, train_loss = 3.1525, dev_loss = 3.2052, dev_acc = 0.2264
# After round 99, train_loss = 3.1503, dev_loss = 3.1914, dev_acc = 0.2265
# After round 100, train_loss = 3.1436, dev_loss = 3.1802, dev_acc = 0.2316
# Total training time: 7158.40 seconds

# %%
plt.plot([i + 1 for i in range(len(history_dfl))], [history_dfl[i][0] for i in range(len(history_dfl))], color='r', label='train accuracy')
plt.plot([i + 1 for i in range(len(history_dfl))], [history_dfl[i][1] for i in range(len(history_dfl))], color='b', label='dev accuracy')
plt.legend()
plt.title("Rounds vs Accuracy")
plt.xlabel("Number of rounds")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# HDFL

# %%
class Client:
    def __init__(self, client_id, dataset, test_loader):
        self.client_id = client_id
        self.dataset = dataset
        self.kmt = KMT(dataset, index=np.arange(len(dataset)), test_loader=test_loader)
        self.client_data=[]
        self.server_id=-1
        self.distance=random.randint(1,100)

    def set_server_id(self,client_id):
        self.client_data_server=[]
        self.server_id=client_id
    
    def get_server_id(self):
        return self.server_id

    def get_dataset_size(self):
        return len(self.dataset)
    
    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict, other_soft_decisions=None):
        # Load initial parameters
        self.kmt.model.load_state_dict(parameters_dict)

        # Standard training
        self.kmt.train()

        # Knowledge distillation using soft labels from other clients (if available)
        if other_soft_decisions is not None:
            for images, labels in self.kmt.train_loader:
                if images in other_soft_decisions:
                    other_soft_decision = other_soft_decisions[images]
                    self.kmt.distillation_train(images, labels, other_soft_decision)
        
        # Return the updated model parameters
        return self.kmt.model.state_dict()

    def recieve_parameters(self, client_id, client_parameter, fraction):
        client_object = {"client_id": client_id, "client_parameter": client_parameter, "fraction": fraction}
        self.client_data.append(client_object)

    def aggregated_parameters(self):
        local_aggregated_model = None
        for i in range(len(self.client_data)):
            local_aggregated_model = average_models(local_aggregated_model, self.client_data[i]["client_parameter"], self.client_data[i]["fraction"])
        self.client_data.clear()
        return local_aggregated_model
    
    def recieve_data_as_server(self,client_parameter,fraction):
        client_object={"client_parameter":client_parameter,"fraction":fraction}
        self.client_data_server.append(client_object)
    

    def aggregate_parameter_as_server(self):
         local_aggregated_model_as_server=None
         for data in self.client_data_server:
              local_aggregated_model_as_server=average_models(local_aggregated_model_as_server,data["client_parameter"],data["fraction"])
         self.client_data_server.clear()
         return local_aggregated_model_as_server

# %%
def utility_function(client_set_1,client_set_2,data):
  client_set_1_average=None
  client_set_2_average=None
  for i in client_set_1:
    client_set_1_average=average_models(client_set_1_average,data[i],1)
  for i in client_set_2:
    client_set_2_average=average_models(client_set_2_average,data[i],1)
  model1_weights = []
  model2_weights = []
  for key, value in client_set_1_average.items():
      model1_weights.append(value.detach().cpu())

  for key, value in client_set_2_average.items():
      model2_weights.append(value.detach().cpu())
  weight1_flat = torch.cat([param.view(-1) for param in model1_weights])
  weight2_flat = torch.cat([param.view(-1) for param in model2_weights])
  cosine_sim = torch.nn.functional.cosine_similarity(weight1_flat, weight2_flat, dim=0)
  return cosine_sim.item()

# %%
def generateGroupsGame(data,num_clients):
    groups=[]
    for i in range(0,num_clients):
        groups.append([i])
    while True:
        for group in groups:
            for x in group:
                no_change_flag=0
                m_i_n_group=None
                m_i_n_utility=100
                minu=0
                for g in groups:
                    if g!=group:
                        if len(g) >= 1 and len(group) > 1:
                            tempset_1=g.copy()
                            tempset_1.append(x)
                            tempset_2=group.copy()
                            tempset_2.remove(x)
                            if utility_function(tempset_1,tempset_2,data) > utility_function(g,group,data): 
                                if minu < utility_function(tempset_1,tempset_2,data):
                                    m_i_n_group=g
                                    minu=utility_function(tempset_1,tempset_2,data)        
                        elif len(group)<=1:
                            if utility_function(g,group,data) < m_i_n_utility:
                                m_i_n_group=g
                                m_i_n_utility=utility_function(g,group,data)
                if m_i_n_group is not None:  
                    group.remove(x)
                    m_i_n_group.append(x)
                    no_change_flag=1
                    if len(group) <=0 :
                        groups.remove(group)
        if no_change_flag == 0:
            break
    print("end")
    return groups

# %%
def groupDataLength(groups,clients):
    group_dataset_length=[]
    for grp in groups:
        totalcount=0
        for clt in grp:
            totalcount+=clients[clt].get_dataset_size()
        group_dataset_length.append(totalcount)
    return group_dataset_length

# %%
from torch.utils.data import Subset

# Example: Split `dataset` into `num_clients` subsets
client_datasets = []
dataset_size = len(train_dataset)
subset_size = dataset_size // num_clients
test_loader = DataLoader(test_dataset, batch_size=200, shuffle=True)

# Split the dataset into chunks for each client
for i in range(num_clients):
    indices = range(i * subset_size, (i + 1) * subset_size)
    client_datasets.append(Subset(train_dataset, indices))

# Now initialize the clients
clients = [Client(i, client_datasets[i], test_loader) for i in range(num_clients)]

# %%
global_net = to_device(FederatedNet(), device)
curr_parameters = global_net.state_dict()
data = []
for client in clients:
    paramerter=client.train(curr_parameters)
    data.append(paramerter)

groups=generateGroupsGame(data,num_clients)
print(groups)
group_dataset_length=groupDataLength(groups,clients)
# Out:
# end
# [[3, 20, 67, 13, 43, 52, 54, 63, 22], [5], [6, 62, 29], [11, 24, 64], [15, 30], [47], [10], [23], [9, 28, 57], [27, 0], [16], [32, 41], [26, 31], [35], [4, 34, 1], [39], [38], [46], [66, 18, 8], [14, 21], [50, 2, 51, 48], [53, 17], [56, 49], [58, 61], [60, 33, 55], [59, 25], [65, 42, 40, 7], [68, 12, 36, 45, 44], [69, 19, 37]]

# %%
hdfl_start_time = time.time()

global_net = to_device(FederatedNet(), device)
curr_parameters = global_net.state_dict()
history_hdfl = []
weights = []
traffic = []
load_model = None
total_data_size = len(train_dataset)
learning_rate = 8e-2


for i in range(rounds):
    new_model = None
    soft_decisions = {}  # Dictionary to store each client's soft decisions for distillation

    # Step 1: Each client performs training and generates soft decisions
    for client in clients:
        fraction = client.get_dataset_size() / total_data_size

        # Each client trains on its dataset, possibly using other clients' soft decisions for distillation
        client_parameters = client.train(curr_parameters, other_soft_decisions=soft_decisions if i > 0 else None)
        
        # Gather soft decisions for this client's data to use in distillation
        for images, labels in client.kmt.train_loader:
            output = client.kmt.model(images)
            soft_decisions[images] = torch.softmax(output, dim=1).detach()

        # Share parameters with other clients for aggregation
        for clt in clients:
            clt.recieve_parameters(client.get_client_id(), client_parameters, fraction)

        # Aggregate models across all clients
        new_model = average_models(new_model, client_parameters, fraction)

    # Update the global model and evaluate
    load_model = new_model.copy()
    global_net.load_state_dict(new_model)
    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(test_dataset)
    
    # Logging
    print(f'After round {i + 1}, train_loss = {round(train_loss, 4)}, dev_loss = {round(dev_loss, 4)}, dev_acc = {round(dev_acc, 4)}')
    history_hdfl.append((train_acc, dev_acc, i))
    traffic.append((num_clients) * (num_clients - 1))

# Calculate total time
hdfl_end_time = time.time()
hdfl_time = hdfl_end_time - hdfl_start_time
print(f"Total training time: {hdfl_time:.2f} seconds")

# Optionally save the final global model if needed
torch.save(global_net.state_dict(), "final_global_model.pt")
# Out:
# After round 1, train_loss = 4.5997, dev_loss = 4.6019, dev_acc = 0.0134
# After round 2, train_loss = 4.5883, dev_loss = 4.5902, dev_acc = 0.0156
# After round 3, train_loss = 4.5755, dev_loss = 4.5745, dev_acc = 0.0201
# After round 4, train_loss = 4.5535, dev_loss = 4.5575, dev_acc = 0.022
# After round 5, train_loss = 4.5179, dev_loss = 4.5191, dev_acc = 0.0278
# After round 6, train_loss = 4.4738, dev_loss = 4.4741, dev_acc = 0.0323
# After round 7, train_loss = 4.4274, dev_loss = 4.426, dev_acc = 0.0381
# After round 8, train_loss = 4.3792, dev_loss = 4.3827, dev_acc = 0.0449
# After round 9, train_loss = 4.3373, dev_loss = 4.3357, dev_acc = 0.0497
# After round 10, train_loss = 4.2941, dev_loss = 4.2996, dev_acc = 0.052
# After round 11, train_loss = 4.2519, dev_loss = 4.2553, dev_acc = 0.0544
# After round 12, train_loss = 4.2154, dev_loss = 4.2193, dev_acc = 0.0595
# After round 13, train_loss = 4.1749, dev_loss = 4.1805, dev_acc = 0.0623
# After round 14, train_loss = 4.1392, dev_loss = 4.1488, dev_acc = 0.0707
# After round 15, train_loss = 4.1082, dev_loss = 4.1228, dev_acc = 0.0676
# After round 16, train_loss = 4.0793, dev_loss = 4.0899, dev_acc = 0.0759
# After round 17, train_loss = 4.0544, dev_loss = 4.0673, dev_acc = 0.0793
# After round 18, train_loss = 4.0238, dev_loss = 4.0355, dev_acc = 0.0779
# After round 19, train_loss = 4.0012, dev_loss = 4.0236, dev_acc = 0.0811
# After round 20, train_loss = 3.9722, dev_loss = 3.9915, dev_acc = 0.0937
# After round 21, train_loss = 3.9494, dev_loss = 3.9683, dev_acc = 0.0909
# After round 22, train_loss = 3.9354, dev_loss = 3.9416, dev_acc = 0.0949
# After round 23, train_loss = 3.9181, dev_loss = 3.915, dev_acc = 0.1014
# After round 24, train_loss = 3.8917, dev_loss = 3.9126, dev_acc = 0.0973
# After round 25, train_loss = 3.8768, dev_loss = 3.8889, dev_acc = 0.1057
# After round 26, train_loss = 3.86, dev_loss = 3.883, dev_acc = 0.1037
# After round 27, train_loss = 3.8378, dev_loss = 3.8584, dev_acc = 0.1143
# After round 28, train_loss = 3.8215, dev_loss = 3.8406, dev_acc = 0.1158
# After round 29, train_loss = 3.807, dev_loss = 3.8238, dev_acc = 0.1147
# After round 30, train_loss = 3.7938, dev_loss = 3.8119, dev_acc = 0.1158
# After round 31, train_loss = 3.7724, dev_loss = 3.7974, dev_acc = 0.1208
# After round 32, train_loss = 3.7571, dev_loss = 3.781, dev_acc = 0.1262
# After round 33, train_loss = 3.7452, dev_loss = 3.7566, dev_acc = 0.1296
# After round 34, train_loss = 3.7268, dev_loss = 3.7551, dev_acc = 0.1302
# After round 35, train_loss = 3.7108, dev_loss = 3.7341, dev_acc = 0.1327
# After round 36, train_loss = 3.6985, dev_loss = 3.7233, dev_acc = 0.1283
# After round 37, train_loss = 3.6868, dev_loss = 3.711, dev_acc = 0.136
# After round 38, train_loss = 3.673, dev_loss = 3.6975, dev_acc = 0.1428
# After round 39, train_loss = 3.6607, dev_loss = 3.6775, dev_acc = 0.1438
# After round 40, train_loss = 3.6451, dev_loss = 3.666, dev_acc = 0.1473
# After round 41, train_loss = 3.6382, dev_loss = 3.6592, dev_acc = 0.1482
# After round 42, train_loss = 3.6204, dev_loss = 3.638, dev_acc = 0.1482
# After round 43, train_loss = 3.6112, dev_loss = 3.6312, dev_acc = 0.1478
# After round 44, train_loss = 3.5993, dev_loss = 3.6225, dev_acc = 0.1512
# After round 45, train_loss = 3.5883, dev_loss = 3.6149, dev_acc = 0.1507
# After round 46, train_loss = 3.5783, dev_loss = 3.6117, dev_acc = 0.1516
# After round 47, train_loss = 3.5627, dev_loss = 3.5897, dev_acc = 0.1562
# After round 48, train_loss = 3.5495, dev_loss = 3.5742, dev_acc = 0.1614
# After round 49, train_loss = 3.5425, dev_loss = 3.5684, dev_acc = 0.1609
# After round 50, train_loss = 3.5311, dev_loss = 3.5497, dev_acc = 0.161
# After round 51, train_loss = 3.5213, dev_loss = 3.5455, dev_acc = 0.1652
# After round 52, train_loss = 3.5061, dev_loss = 3.5443, dev_acc = 0.1627
# After round 53, train_loss = 3.5012, dev_loss = 3.535, dev_acc = 0.1682
# After round 54, train_loss = 3.4892, dev_loss = 3.5265, dev_acc = 0.1686
# After round 55, train_loss = 3.4813, dev_loss = 3.514, dev_acc = 0.1691
# After round 56, train_loss = 3.4725, dev_loss = 3.5059, dev_acc = 0.1733
# After round 57, train_loss = 3.4628, dev_loss = 3.5004, dev_acc = 0.1703
# After round 58, train_loss = 3.4578, dev_loss = 3.4891, dev_acc = 0.1767
# After round 59, train_loss = 3.4441, dev_loss = 3.4745, dev_acc = 0.1754
# After round 60, train_loss = 3.4306, dev_loss = 3.4681, dev_acc = 0.1784
# After round 61, train_loss = 3.4276, dev_loss = 3.4605, dev_acc = 0.1822
# After round 62, train_loss = 3.4162, dev_loss = 3.4583, dev_acc = 0.1797
# After round 63, train_loss = 3.4085, dev_loss = 3.4394, dev_acc = 0.1841
# After round 64, train_loss = 3.3999, dev_loss = 3.4377, dev_acc = 0.184
# After round 65, train_loss = 3.395, dev_loss = 3.4158, dev_acc = 0.1832
# After round 66, train_loss = 3.3821, dev_loss = 3.4184, dev_acc = 0.1864
# After round 67, train_loss = 3.3766, dev_loss = 3.4132, dev_acc = 0.1884
# After round 68, train_loss = 3.3644, dev_loss = 3.4056, dev_acc = 0.185
# After round 69, train_loss = 3.3605, dev_loss = 3.4065, dev_acc = 0.1894
# After round 70, train_loss = 3.3532, dev_loss = 3.3879, dev_acc = 0.1936
# After round 71, train_loss = 3.3429, dev_loss = 3.3759, dev_acc = 0.1994
# After round 72, train_loss = 3.3363, dev_loss = 3.375, dev_acc = 0.2006
# After round 73, train_loss = 3.3265, dev_loss = 3.3578, dev_acc = 0.1965
# After round 74, train_loss = 3.3224, dev_loss = 3.3658, dev_acc = 0.2009
# After round 75, train_loss = 3.3105, dev_loss = 3.3563, dev_acc = 0.1972
# After round 76, train_loss = 3.3029, dev_loss = 3.3401, dev_acc = 0.1976
# After round 77, train_loss = 3.2991, dev_loss = 3.3444, dev_acc = 0.1983
# After round 78, train_loss = 3.2891, dev_loss = 3.3356, dev_acc = 0.2
# After round 79, train_loss = 3.2817, dev_loss = 3.3163, dev_acc = 0.2045
# After round 80, train_loss = 3.2724, dev_loss = 3.3208, dev_acc = 0.2043
# After round 81, train_loss = 3.2686, dev_loss = 3.3112, dev_acc = 0.2025
# After round 82, train_loss = 3.2621, dev_loss = 3.2976, dev_acc = 0.2057
# After round 83, train_loss = 3.2531, dev_loss = 3.3022, dev_acc = 0.2087
# After round 84, train_loss = 3.249, dev_loss = 3.2962, dev_acc = 0.2094
# After round 85, train_loss = 3.2364, dev_loss = 3.2861, dev_acc = 0.2047
# After round 86, train_loss = 3.2319, dev_loss = 3.272, dev_acc = 0.2154
# After round 87, train_loss = 3.2238, dev_loss = 3.274, dev_acc = 0.2131
# After round 88, train_loss = 3.22, dev_loss = 3.2634, dev_acc = 0.2129
# After round 89, train_loss = 3.2116, dev_loss = 3.2668, dev_acc = 0.2096
# After round 90, train_loss = 3.2063, dev_loss = 3.2617, dev_acc = 0.2152
# After round 91, train_loss = 3.1992, dev_loss = 3.2561, dev_acc = 0.2173
# After round 92, train_loss = 3.191, dev_loss = 3.2418, dev_acc = 0.2164
# After round 93, train_loss = 3.1838, dev_loss = 3.2215, dev_acc = 0.221
# After round 94, train_loss = 3.1768, dev_loss = 3.223, dev_acc = 0.2228
# After round 95, train_loss = 3.1741, dev_loss = 3.222, dev_acc = 0.2252
# After round 96, train_loss = 3.167, dev_loss = 3.2146, dev_acc = 0.225
# After round 97, train_loss = 3.158, dev_loss = 3.2089, dev_acc = 0.2229
# After round 98, train_loss = 3.1566, dev_loss = 3.205, dev_acc = 0.2207
# After round 99, train_loss = 3.1484, dev_loss = 3.1989, dev_acc = 0.2257
# After round 100, train_loss = 3.1466, dev_loss = 3.188, dev_acc = 0.2252
# Total training time: 7040.26 seconds

# %%
plt.plot([i + 1 for i in range(len(history_hdfl))], [history_hdfl[i][0] for i in range(len(history_hdfl))], color='r', label='train accuracy')
plt.plot([i + 1 for i in range(len(history_hdfl))], [history_hdfl[i][1] for i in range(len(history_hdfl))], color='b', label='dev accuracy')
plt.legend()
plt.title("Rounds vs Accuracy")
plt.xlabel("Number of rounds")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.plot([i + 1 for i in range(len(history_FL))], [history_FL[i][1] for i in range(len(history_FL))], color='b', label='FL dev accuracy')
plt.plot([i + 1 for i in range(len(history_dfl))], [history_dfl[i][1] for i in range(len(history_dfl))], color='r', label='DFL dev accuracy')
plt.plot([i + 1 for i in range(len(history_hdfl))], [history_hdfl[i][1] for i in range(len(history_hdfl))], color='g', label='HDFL dev accuracy')
plt.legend()
plt.title("Rounds vs Accuracy on CIFAR100")
plt.xlabel("Number of rounds")
plt.ylabel("Accuracy")
plt.show()

# %%
labels = ['FL', 'DFL', 'HDFL']
values = [fl_time, dfl_time, hdfl_time]

# Plot the bar graph
plt.bar(labels, values, color=['blue', 'green', 'red'])

# Add labels and title
plt.xlabel('')
plt.ylabel('RUN TIME')
plt.title('Run Time for FL, DFL & HDFL')

# Show the plot
plt.show()
